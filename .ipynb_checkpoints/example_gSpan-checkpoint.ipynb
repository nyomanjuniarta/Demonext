# %%
from gspan_mining.config import parser
from gspan_mining.main import main
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\compat\_optional.py:124: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# python -m gspan_mining [-s min_support] [-n num_graph] [-l min_num_vertices] [-u max_num_vertices]
# [-d True/False] [-v True/False verbose] [-p True/False] [-w True/False] [-h] database_file_name 
args_str = '-s 2 -d False small.txt'
FLAGS, _ = parser.parse_known_args(args=args_str.split())

# %%
gs = main(FLAGS)
# Out:
# t # 0
# v 0 2
# v 1 4
# e 0 1 0
#
# Support: 2
#
# -----------------
#
# t # 1
# v 0 2
# v 1 4
# v 2 3
# e 0 1 0
# e 1 2 0
#
# Support: 2
#
# -----------------
#
# t # 2
# v 0 3
# v 1 4
# e 0 1 0
#
# Support: 2
#
# -----------------
#
# Read:	0.09 s
# Mine:	0.7200000000000001 s
# Total:	0.81 s

# %%
for g in gs.graphs.values():
    g.plot()
